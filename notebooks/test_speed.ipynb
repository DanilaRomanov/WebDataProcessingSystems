# %% [markdown]
# ### Import libraries and functions

# %%
import spacy
import pandas as pd
import numpy as np
import re
import requests
import sys
from tqdm import tqdm
from pathlib import Path

sys.path.insert(0, "../")
# Imports for NLP
from nlp import beautifulsoup as bsp
from nlp import nlp_preprocessing as nlp_prep
from nlp.read_warc2 import read_warc
from corpus_processing import ner
from corpus_processing import relation_extraction as re
from corpus_processing import relation_linking as rl
from corpus_processing import entity_linking as el 
from nlp import coref as cr

# %% [markdown]
# ### Load WARC data

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# autoreload
# %load_ext autoreload
# %autoreload 2

DIR_DATA = Path("../data/warcs")
FNAME_WARC = "sample.warc.gz"

# %%
warc_df = read_warc(DIR_DATA / FNAME_WARC)
# Out:
# reading warc file...
# warc list ['clueweb12-0000tw-00-00006' 'clueweb12-0000tw-00-00043'
#  'clueweb12-0000tw-00-00044' 'clueweb12-0000tw-00-00101'
#  'clueweb12-0000tw-00-00129' 'clueweb12-0000tw-00-00130'
#  'clueweb12-0000tw-00-00141' 'clueweb12-0000tw-00-00160'
#  'clueweb12-0000tw-00-00161' 'clueweb12-0000tw-00-00162'
#  'clueweb12-0000tw-00-00199' 'clueweb12-0000tw-00-00205'
#  'clueweb12-0000tw-00-00210' 'clueweb12-0000tw-00-00212'
#  'clueweb12-0000tw-00-00214' 'clueweb12-0000tw-00-00829'
#  'clueweb12-0000tw-00-00833' 'clueweb12-0000tw-00-00834'
#  'clueweb12-0000tw-00-00835' 'clueweb12-0000tw-00-00836'
#  'clueweb12-0000tw-00-00837' 'clueweb12-0000tw-00-00843'
#  'clueweb12-0000tw-00-00844' 'clueweb12-0000tw-00-00877'
#  'clueweb12-0000tw-00-00879' 'clueweb12-0000tw-00-00880'
#  'clueweb12-0000tw-00-00881' 'clueweb12-0000tw-00-00941'
#  'clueweb12-0000tw-00-00942' 'clueweb12-0000tw-00-00943'
#  'clueweb12-0000tw-00-00944' 'clueweb12-0000tw-00-00946']

# %%
warc_df
# Out:
#                                              HTML_DOC  \
# 0   <html>\r\n\r\n<head>\r\n<meta http-equiv="Cont...
# 1   <html>\n\n<head>\n\n<style type="text/css">\n\...
# 2   <html>\n<head>\n<style type="text/css">\n#bott...
# 3   <html>\n<head>\n\n<title>DHP Concerts Bristol ...
# 4   <html>\n<head>\n   <title>12 Tourist Spots in ...
# 5   <html>\r\n<head>\r\n<title>Saving Money Buying...
# 6   <html>\n<head>\n    <title>Freelance Web Desig...
# 7   <html>\n<head>\n<meta http-equiv="Content-Type...
# 8   <html>\n<head>\n    <meta http-equiv="Content-...
# 9   <html>\n<head>\n    <meta http-equiv="Content-...
# 10  <html>\n<head><script type="text/javascript">v...
# 11  <html>\n<head>\n\t<title>Browse all 1117 sessi...
# 12  <html>\r\n\t<head>\r\n\t\t\r\n<title>WeatherBu...
# 13  <html>\r\n\t<head>\r\n\t\t\r\n<title>WeatherBu...
# 14  <html>\r\n\t<head>\r\n\r\n\r\n<script language...
# 15  <html>\n\t<head>\n\t\t<title>Sokoblovsky Farms...
# 16  <html>\r\n    <head><title>\r\n\t\r\n    \r\n ...
# 17  <html>\r\n    <head><title>\r\n\t\r\n    \r\n ...
# 18  <html>\r\n    <head><title>\r\n\t\r\n    \r\n ...
# 19  <html>\r\n    <head><title>\r\n\t\r\n    \r\n ...
# 20  <html>\n<head>\n    <meta http-equiv="Content-...
# 21  <html> \n    \t\t\t<head> \n    \t\t\t<meta ht...
# 22  <html> \n    \t\t\t<head> \n    \t\t\t<meta ht...
# 23  <html>\n<head>\n<title>HIPSTART</title>\n<link...
# 24  <html>\n    <head>\n        <meta http-equiv="...
# 25  <html>\n    <head>\n        <meta http-equiv="...
# 26  <html>\n    <head>\n        <meta http-equiv="...
# 27  <html>\n\t<head>\n        <title>Edinburgh Sci...
# 28  <html>\n\t<head>\n        <title>KyNa Twitter ...
# 29  <html>\n\t<head>\n        <title>New Comm Biz ...
# 30  <html>\n\t<head>\n        <title>Ticket Shack ...
# 31  <html>\n<head>\n<!-- test that deploys are wor...
#
#                  WARC-TREC-ID
# 0   clueweb12-0000tw-00-00006
# 1   clueweb12-0000tw-00-00043
# 2   clueweb12-0000tw-00-00044
# 3   clueweb12-0000tw-00-00101
# 4   clueweb12-0000tw-00-00129
# 5   clueweb12-0000tw-00-00130
# 6   clueweb12-0000tw-00-00141
# 7   clueweb12-0000tw-00-00160
# 8   clueweb12-0000tw-00-00161
# 9   clueweb12-0000tw-00-00162
# 10  clueweb12-0000tw-00-00199
# 11  clueweb12-0000tw-00-00205
# 12  clueweb12-0000tw-00-00210
# 13  clueweb12-0000tw-00-00212
# 14  clueweb12-0000tw-00-00214
# 15  clueweb12-0000tw-00-00829
# 16  clueweb12-0000tw-00-00833
# 17  clueweb12-0000tw-00-00834
# 18  clueweb12-0000tw-00-00835
# 19  clueweb12-0000tw-00-00836
# 20  clueweb12-0000tw-00-00837
# 21  clueweb12-0000tw-00-00843
# 22  clueweb12-0000tw-00-00844
# 23  clueweb12-0000tw-00-00877
# 24  clueweb12-0000tw-00-00879
# 25  clueweb12-0000tw-00-00880
# 26  clueweb12-0000tw-00-00881
# 27  clueweb12-0000tw-00-00941
# 28  clueweb12-0000tw-00-00942
# 29  clueweb12-0000tw-00-00943
# 30  clueweb12-0000tw-00-00944
# 31  clueweb12-0000tw-00-00946

# %%
selected_doc = warc_df.iloc[18]
stripped_webpage = bsp.scrape_webpage(selected_doc['HTML_DOC'])

# %%
spacy_processor = spacy.load("en_core_web_trf")
spacy_doc = nlp_prep.get_nlp_doc(stripped_webpage, spacy_processor)
processed_page = nlp_prep.nlp_preprocessing(spacy_doc)

# %%
ner_page = ner.detect_entities(spacy_doc)
ner_page
# Out:
#                 label  ner_type
# 0           UP TO 50%   PERCENT
# 1         8 hours ago      TIME
# 2         @mduscavage    PERSON
# 3         5 hours ago      TIME
# 4                  OP    PERSON
# 5          mduscavage    PERSON
# 7               first   ORDINAL
# 8         3 hours ago      TIME
# 17                REI       ORG
# 18           2/9/12 9      TIME
# 19            REI.com       ORG
# 20     1-800-426-4840  CARDINAL
# 22               U.S.       GPE
# 23        2 hours ago      TIME
# 24          Toblerone   PRODUCT
# 25        an hour ago      TIME
# 26                 34  CARDINAL
# 27                 10  CARDINAL
# 28                  4  CARDINAL
# 29               Woot       ORG
# 30  Woot Services LLC       ORG
# 31             Deals.       ORG
# 36          2004-2012      DATE
# 37              Deals       ORG
# 42         Deals.Woot       ORG
# 45       five minutes      TIME

# %%
allowed_entity_types = ['PERSON', 'NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW', 'LANGUAGE', 'DATE']

# Filter out entities that are not in allowed_entity_types
filtered_entities = ner_page.loc[ner_page['ner_type'].isin(allowed_entity_types), 'label']
filtered_entities
# Out:
# 2           @mduscavage
# 4                    OP
# 5            mduscavage
# 17                  REI
# 19              REI.com
# 22                 U.S.
# 24            Toblerone
# 29                 Woot
# 30    Woot Services LLC
# 31               Deals.
# 36            2004-2012
# 37                Deals
# 42           Deals.Woot
# Name: label, dtype: object

# %%
candidate_list = []
candidate_indices = []
for entity in tqdm(filtered_entities, desc="Entity"):
    candidates = el._get_wikipedia_articles(entity)
    if candidates != []:
        candidate_indices.append(int(len(candidates)))

    candidate_list += candidates
# Out:
# Entity: 100%|██████████| 13/13 [00:04<00:00,  2.81it/s]

# %%
candidate_indices
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %%
candidate_views = el.p.article_views("en.wikipedia", candidate_list, granularity="monthly", start="2022100100", end="2022103100")
print(list(candidate_views.values())[0])
# Out:
# {'OP': 3233, 'Op-ed': 18916, 'Op._cit.': 3196, 'Takt_Op': 12025, 'Photo_op': 3353, 'Cooperative_video_game': 8332, 'Operational_amplifier': 36895, 'KO_OP': 467, 'OP_Financial_Group': 2381, 'Op_art': 19766, 'REI': 13781, 'Rei': 1185, 'Rei_Rei': 776, 'Rei_Ayanami': 14435, 'Reis': 613, 'Cristo_Rei': 172, 'Sailor_Mars': 11012, 'Rei_(given_name)': 3261, 'Rei_Harakami': 1050, 'Rei_Kawakubo': 9795, 'Deus_Salve_o_Rei': 1776, 'Novara_(company)': 791, 'Lead_climbing': 5891, 'Figure_8_(belay_device)': 970, 'Compass': 46107, 'Sierra_Nevada': 32851, 'U.S._state': 361176, 'United_States': 1775677, 'Georgia_(U.S._state)': 189548, 'U.S._Agent': 12962, 'U.S._Cremonese': 32611, 'U.S._Lecce': 29031, 'U.S._Bancorp': 26614, 'U.S._Steel': 22078, 'U-S-A!': 2284, 'U.S._Woodland': 8811, 'Toblerone': 49590, 'Toblerone_line': 5114, 'Mona_Sahlin': 2451, "Dragon's_teeth_(fortification)": 39080, 'Theodor_Tobler': 940, "Terry's_Chocolate_Orange": 8462, 'Shrinkflation': 11350, 'Heroes_(confectionery)': 2032, 'Japanese_slipper': 1472, 'Milk_chocolate': 12942, 'Woot': 6033, 'Woot_(disambiguation)': 72, 'Matt_Rutledge': 900, 'Whoot,_There_It_Is': 1039, 'The_Tin_Woodman_of_Oz': 1382, 'WOOT-LD': 278, 'W00t': 1911, 'IMDb': 268887, 'Stone_Brewing_Co.': 2381, 'Jeff_Bezos': 561044, 'Amazon_Web_Services': 111202, 'List_of_Amazon_products_and_services': 18594, 'Blink_Home': 4111, 'Ring_(company)': 26233, 'Amazon_(company)': 776000, 'Amazon_Appstore': 68112, 'Criticism_of_Amazon': 15335, 'List_of_mergers_and_acquisitions_by_Amazon': 13513, 'Prime_Now': 1793, 'Deals': 939, 'Deal_or_No_Deal': 16234, 'Deal_or_No_Deal_(album)': 1790, 'Deal': 1361, 'Frank_Deal': 931, 'New_Deal': 67647, 'Deal_with_the_Devil': 37659, 'Deal_with_It': 97, 'Deal_With_It!': 281, 'Deal_or_No_Deal_Nigeria': 174, 'Brenda_Strong': 26010, 'Erin_Andrews': 85525, 'Souvenir:_The_Singles_2004–2012': 480, 'Teri_Hatcher': 208503, 'Jesse_Spencer': 61041, '2004': 20576, 'Volvo_S40': 15198, 'Tate_Reeves': 9822, 'UEFA_Euro_2004': 34892, 'UEFA_European_Championship_records_and_statistics': None, 'Deal_or_No_Deal_(American_game_show)': 22191, 'Steals_and_Deals': 2230, 'Deal_of_the_day': 1389, 'OfficeArrow': 58, 'Meh': 8467, 'Amazon_Prime_Video': 288516, "The_Wife_of_Bath's_Tale": 13090, 'Amazon_Freevee': 34692, 'Twitch_(service)': 402008}

# %%
first_key = list(candidate_views.keys())[0]
candidate_tuple_array = np.array(list(candidate_views[first_key].items()))

# split candidate_views into chunks of size candidate_indices
candidate_tuple_array = np.split(candidate_tuple_array, np.cumsum(candidate_indices)[:-1])
# make second
# for chunk in candidate_tuple_array:
#     print(np.argmax(np.max(chunk[:][1], axis=0)))

# %%
def determine_max_views(x):
    # make second column into integer
    x[:,1] = x[:,1].astype(int)
    # return index of max value
    return np.argmax(x[:,1], axis=0)

# %%
candidate_tuple_array[0][0]
# Out:
# array(['OP', 3233], dtype=object)

# %%
determine_max_views(candidate_tuple_array[0])
# Out:
# 6
